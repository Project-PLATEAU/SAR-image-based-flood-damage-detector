# %% [markdown]
# ## Git2Colab_Installation_PLATEAU_FloodSAR
# SAR-image-based-flood-damage-detectorをGoogleドライブに展開します。
# メニューバーの「ランタイム」より「すべてのセルを実行」してください。
# その後、出てくる警告やアクセス許可を通してください。

# %%
### Googleドライブにリポジトリをクローンしてくる
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/MyDrive/
# !git clone https://github.com/Project-PLATEAU/SAR-image-based-flood-damage-detector.git
# %cd plateau-2023-uc01-satellite-analytics
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
# Cloning into 'plateau-2023-uc01-satellite-analytics'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 32 (delta 7), reused 10 (delta 0), pack-reused 0
# Receiving objects: 100% (32/32), 5.26 MiB | 12.49 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/drive/MyDrive/plateau-2023-uc01-satellite-analytics

# %%
# @title 浸水推定モデルのチェックポイントのダウンロード
# !mkdir PLATEAU-FloodSAR/models
# %cd PLATEAU-FloodSAR/models

# !gdown https://assets.cms.plateau.reearth.io/assets/36/fe406e-8261-4e95-952b-2747266e3537/model_epoch_vv_119.pth
# !gdown https://assets.cms.plateau.reearth.io/assets/59/c4a445-6a85-4be1-b3fb-fc716c573847/model_epoch_aug_mask_100.pth
# %cd ../../

# %% [markdown]
# ### サンプルの実行（内容を変更する場合はドライブに保存されたファイルを使用してください）
# 順に実行していく（指定範囲によっては全てを実行するのに1時間以上かかります）
# - [0_PrepareProject.ipynb](https://colab.research.google.com/github/Project-PLATEAU/SAR-image-based-flood-damage-detector/blob/main/PLATEAU-FloodSAR/0_PrepareProject.ipynb)
# - [1_EstimateSAR_FloodPrbDiff.ipynb](https://colab.research.google.com/github/Project-PLATEAU/SAR-image-based-flood-damage-detector/blob/main/PLATEAU-FloodSAR/1_EstimateSAR_FloodPrbDiff.ipynb)
# - [2_GeneratePointGroup.ipynb](https://colab.research.google.com/github/Project-PLATEAU/SAR-image-based-flood-damage-detector/blob/main/PLATEAU-FloodSAR/2_GeneratePointGroup.ipynb)
# - [3_CalcFloodDEMRaster.ipynb](https://colab.research.google.com/github/Project-PLATEAU/SAR-image-based-flood-damage-detector/blob/main/PLATEAU-FloodSAR/3_CalcFloodDEMRaster.ipynb)
# - [4_AssessBuildings.ipynb](https://colab.research.google.com/github/Project-PLATEAU/SAR-image-based-flood-damage-detector/blob/main/PLATEAU-FloodSAR/4_AssessBuildings.ipynb)
# - [5_Upload.ipynb](https://colab.research.google.com/github/Project-PLATEAU/SAR-image-based-flood-damage-detector/blob/main/PLATEAU-FloodSAR/5_Upload.ipynb)
